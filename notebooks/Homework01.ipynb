# %% [markdown]
# # Homework 1: Variables, arithmetic, and arrays

# %% [markdown]
# Covers **Lecture 1** (variables, arithmetic, printing) and **Lecture 2** (NumPy arrays).

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# The `ipynb` file type is the only accepted format.
#
# Save a copy before beginning. Reloading or disconnecting can revert the notebook to the
# instructor copy.

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Problem 1 (25 pts): Density calculations
#
# For each part, define named variables for every given quantity, compute the result, and
# print it with a labeled f-string. Use `:.2f` (or the format specified) for rounding.
#
# (a) A machined aluminum bracket has mass 54.0 g and volume 20.0 cm$^3$.
# Compute its density and print it labeled, rounded to 2 decimal places.
#
# (b) A titanium pin has mass 90.2 g and volume 20.0 cm$^3$.
# Compute and print its density the same way.
#
# (c) Convert the densities from (a) and (b) to kg/m$^3$ and print each, labeled, rounded
# to 1 decimal place.
#
# (d) A steel bracket has density 7.85 g/cm$^3$ and volume 250.0 cm$^3$.
# Print its mass in grams, rounded to 1 decimal place.

# %%
# your code here

# %% [markdown]
# # Problem 2 (30 pts): Unit conversions and a thermal-expansion report
#
# (a) An aluminum rod has initial length $L_0 = 2.000$ m, thermal expansion coefficient
# $\alpha = 23 \times 10^{-6}\ /^\circ\mathrm{C}$, and is heated by $\Delta T = 60^\circ\mathrm{C}$.
# Using $\Delta L = L_0\,\alpha\,\Delta T$, build a narrated report with four `print()`
# f-string lines matching Lecture 1's template:
# * starting length (3 decimal places)
# * temperature change (no decimals needed)
# * change in length (6 decimal places)
# * final length (6 decimal places)
#
# (b) A temperature change of $60^\circ\mathrm{C}$ is not the same conversion as an absolute reading.
# The correct formula for a change is
# $\Delta T_{^\circ\mathrm{F}} = \Delta T_{^\circ\mathrm{C}} \times \tfrac{9}{5}$. Compute and print the
# Fahrenheit-degree equivalent of the $60^\circ\mathrm{C}$ change from part (a).
#
# (c) A sample has mass 250.0 g. Convert to pounds (1 lb = 453.592 g) and print,
# labeled, rounded to 4 decimal places.

# %%
# your code here

# %% [markdown]
# # Problem 3 (25 pts): Array arithmetic
#
# Eight machined samples of different metals were measured. Their densities (g/cm$^3$) and
# volumes (cm$^3$) are given below, in the same order.

# %%
import numpy as np

density = np.array([2.70, 4.51, 7.85, 8.91, 8.96, 7.14, 10.49, 19.25])   # g/cm^3
volume  = np.array([12.0, 8.5, 15.0, 6.0, 10.0, 9.5, 4.0, 3.0])          # cm^3

# %% [markdown]
# (a) Compute the mass of each sample from `density` and `volume`, then print the result.
#
# (b) The scale has a known +0.05 g calibration offset. Use broadcasting to compute `mass_corrected` and print it.
#
# (c) Convert `mass_corrected` to kilograms and print the result.
#
# (d) Using `.max()` and `.min()`, print the highest and lowest corrected mass. Identify
# which sample index (0-7) has each, using `.argmax()` and `.argmin()`.
#
# (e) The two arrays list samples in the same order.
# If `volume` were sorted from smallest to largest before multiplying, the calculation would still run.
# In one sentence, explain why the result would be physically meaningless.

# %%
# your code here
# your answer to part e as comment or markdown - your choice

# %% [markdown]
# # Problem 4 (20 pts): Materials data types and shapes
#
# No code needed. Give short written answers.
#
# (a) Scalar or array? Include one sentence explaining each choice.
#
# 1. Young's modulus of one aluminum sample
# 2. Density measured on 8 different steel alloys
# 3. The melting point of copper
# 4. Force readings at 500 time steps during a tensile test
#
# (b) For each materials quantity below, what Python type (`int`, `float`, or `str`)? Include one sentence explaining why.
#
# 1. Crystal structure of a material
# 2. Atomic number of an element
# 3. Density in g/cm$^3$
# 4. Number of valence electrons
# 5. A material's name

# %%
# your answers here, as comments or...

# %% [markdown]
# in a markdown cell (your choice)
