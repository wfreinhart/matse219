# %% [markdown]
# Today's topics:
# * getting set up on Colab
# * what is materials informatics?
# * intro to Python syntax
#
# > By the end of today you should be able to compute material densities and convert units in Python

# %% [markdown]
# # Get everyone logged into Colab

# %% [markdown]
# <img src="https://colab.research.google.com/img/colab_favicon_256px.png" width=150 alt="Google Colab logo">
#
# 0. Open the notebook link posted on **Canvas** (already done, you're here!)
# 1. Sign in with your **Penn State credentials** (your Penn State login includes Google services)
# 3. **File → Save a copy in Drive** so you have your own version

# %% [markdown]
# ## Code cells vs. text cells
#
# * **Text cells** - formatted writing (like this one)
# * **Code cells** - Python code, `[ ]` bracket on the left
#
# **Try it:** type the following in a code cell and press the **Play** button (▶) on the left, or **Shift + Enter**:

# %%
print('Hello, materials world!')
# Out:
# Hello, materials world!

# %% [markdown]
# `Shift + Enter` = run cell and advance. Become familiar with Colab's keyboard shortcuts. Ask me for tips!

# %% [markdown]
# ## Cells share memory
#
# A value created in one cell is available in the next:

# %%
mass_g = 4500

# %%
mass_kg = mass_g / 1000
print(mass_kg)
# Out:
# 4.5

# %% [markdown]
# # What is materials informatics?
#
# > “Informatics is the study of computational systems…
# >
# > In some countries, the term ‘informatics’ is used synonymously to mean information systems, information science, information theory, information engineering, …, or other theoretical or practical fields.
# >
# > …universities in continental Europe usually translate ‘informatics’ as computer science, or sometimes information and computer science...
# >
# > In the United States, the term informatics is mostly used in context of data science, library science or its applications in healthcare (health informatics), where it first appeared in the US.”
#
# from [Wikipedia Informatics](https://en.wikipedia.org/wiki/Informatics)

# %% [markdown]
# > “Materials informatics is a field of study that applies the principles of informatics to materials science and engineering to improve the understanding, use, selection, development, and discovery of materials.
# >
# > This is an emerging field, with a goal to achieve high-speed and robust acquisition, management, analysis, and dissemination of diverse materials data with the goal of greatly reducing the time and risk required to develop, produce, and deploy a new materials.”
#
# from [Wikipedia Materials Informatics](https://en.wikipedia.org/wiki/Materials_informatics)

# %% [markdown]
# In short: using data and computation to understand, predict, and design materials.
# Or: “the science of materials **data**”

# %% [markdown]
# The workflow:

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="600" />

# %% [markdown]
# Import, clean, visualize, evaluate, model, optimize. Each step in Python this semester.

# %% [markdown]
# ## Why not do this by hand?
#
# In [a scientific article about High Entropy Alloys](https://doi.org/10.1557/jmr.2018.153) compiled properties for dozens of refractory high-entropy alloys. Manual transcription: hours. Prepared extraction workflow: seconds, reusable, feeds directly into statistics and charts.

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." height="350" />

# %% [markdown]
# [Materials Project](https://materialsproject.org/): computed properties for
# hundreds of thousands of structures, queryable from code.

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="600" />

# %% [markdown]
# ## What do materials data look like?

# %% [markdown]
# **Stress-strain curve**: two columns (strain, stress), one row per time step.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/8/84/Stress_Strain_Ductile_Material.png?utm_source=commons.wikimedia.org&utm_campaign=index&utm_content=original" alt="Schematic stress-strain curve for a ductile material" height=250>

# %% [markdown]
# **XRD pattern**: two columns (2-theta, intensity), hundreds of rows.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/9/95/XRD_Cerium_oxide.gif?utm_source=commons.wikimedia.org&utm_campaign=index&utm_content=original" alt="Cerium oxide x-ray diffraction" height=250>

# %% [markdown]
# **Micrograph**: a 2D grid of pixel intensities, one number per pixel.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/c/cd/CrystalGrain.jpg" alt="Ti alloy grain microstructure" height=250/>
#
# (Ti-5Al-5Mo-5V-1.5Cr after quenching. Edward Pleshakov, [Wikimedia Commons](https://commons.wikimedia.org/wiki/File:CrystalGrain.jpg), [CC BY 3.0](https://creativecommons.org/licenses/by/3.0/))

# %% [markdown]
# **Phase diagram**: boundary coordinates or a grid of phase labels.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/8/85/Pourbaix_Diagram_of_Iron.svg" alt="Iron Pourbaix diagram" height=250/>
#
# (Andel Früh, [Wikimedia Commons](https://commons.wikimedia.org/wiki/File:Pourbaix_Diagram_of_Iron.svg), [CC BY-SA 2.5](https://creativecommons.org/licenses/by-sa/2.5/))

# %% [markdown]
# ## Dimensionality
#
# The **dimensionality** of a piece of data is how many indices it takes to look up a value:
#
# | Dimensionality | What it looks like | Materials example |
# |---|---|---|
# | **Scalar** (0-D) | one number | density of a sample (2.70 g/cm³) |
# | **Vector** (1-D) | a list of numbers | yield strength of 15 bolt specimens |
# | **Matrix** (2-D) | rows and columns | stress-strain curve (two columns, many rows) |
# | **Tensor** (3-D+) | matrix of matrices | a stack of 100 micrograph images (100 x 512 x 512) |
#
# The general term for a data container of any dimensionality is an **array**. A vector is a
# 1-D array, a matrix is a 2-D array, and a tensor is a 3-D or higher array. NumPy
# represents all of these with `numpy.ndarray`, created via `np.array()`.

# %% [markdown]
# ### [Check your understanding]
#
# Scalar, vector, or matrix?
# * Young's modulus of one aluminum sample
# * XRD intensity at 2000 angle steps
# * A 512x512-pixel micrograph

# %% [markdown]
# # Variables and assignment

# %% [markdown]
# A variable stores a value so you can use it later.
#
# `=` means **assign**, not "equals":

# %%
mass_g = 44.5
volume_mL = 5.0

# %%
mass_g
# Out:
# 44.5

# %% [markdown]
# Running a cell with just a variable name shows its value. This only works for the **last line** of a cell.

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="600" />

# %% [markdown]
# Reassignment overwrites the old value. Read right-to-left:

# %%
mass_g = mass_g + 3.0
print(mass_g)
# Out:
# 47.5

# %%
mass_g = 44.5
print(mass_g)
# Out:
# 44.5

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." height="350" />

# %% [markdown]
# ## Naming rules
#
# * letters, digits, underscores only
# * can't start with a digit
# * case-sensitive (`Mass_g` ≠ `mass_g`)
# * convention: **snake_case**

# %%
# EXPECTED-ERROR: this cell intentionally fails
mass g = 44.5
# Out:
#   Cell In[8], line 2
#     mass g = 44.5
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# `SyntaxError` - spaces aren't allowed in names. Fix: `mass_g`
#
# > **Read more:** [W3Schools - Python Variables](https://www.w3schools.com/python/python_variables.asp)

# %% [markdown]
# ## Comments
#
# `#` starts a comment. Python ignores everything after it on that line:

# %%
mass_g = 44.5  # sample mass in grams

# %%
# convert from grams to kilograms
mass_kg = mass_g / 1000

# %%
mass_g = 44.5
volume_mL = 5.0
print(mass_g, volume_mL)   # commas between values print them separated by a space
# Out:
# 44.5 5.0

# %% [markdown]
# ### [Check your understanding]
#
# 1. In the code cell below, create a variable `temp_c` with value `25` and print it
# 2. Try creating a variable name that violates one of the naming rules above. What error do you get?

# %% [markdown]
# # Kinds of materials data
#
# Materials data commonly include three kinds of information:
#
# * **Counts** - how many: atoms per unit cell, number of specimens, valence electrons.
#   Always whole numbers.
# * **Measurements** - how much: density (g/cm³), melting point (°C), yield strength (MPa).
#   Almost never land on a whole number.
# * **Labels** - which one: crystal structure ("FCC"), phase ("austenite"), sample ID ("A7-03").
#   Text, not numbers.
#
# A fourth kind shows up often: **categories** vs. **free text**. "FCC" is one of a small
# set of possible values. "Sample prepared at 1200°C for 2h in Ar atmosphere" is open-ended.
# Both are text, but they behave very differently in analysis.

# %% [markdown]
# # Python types

# %% [markdown]
# Every value has a **type**. Python picks the type based on what the value looks like:

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="600" />

# %%
print(type(mass_g))
print(type(5))
# Out:
# <class 'float'>
# <class 'int'>

# %% [markdown]
# `float` = decimal point. `int` = whole number. Notice the difference:

# %%
print(7)
print(7.0)
# Out:
# 7
# 7.0

# %%
print(type(7))
print(type(7.0))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# `7` is an `int`, `7.0` is a `float`. Division with `/` always returns a `float`.

# %% [markdown]
# ## Strings
#
# Text is a `str`, written with quotes:

# %%
element = "Cu"
print(element)
print(type(element))
# Out:
# Cu
# <class 'str'>

# %% [markdown]
# *What happens when you `+` two strings?*

# %%
reading_1 = '5'
reading_2 = '3'
print(reading_1 + reading_2)
# Out:
# 53

# %% [markdown]
# Two strings: `+` concatenates them into `'53'`.

# %%
print(5 + 3)
# Out:
# 8

# %% [markdown]
# Two integers: `+` adds them to get `8`. Same operator, different behavior based on *type*.
#
# Fix: **type conversion** with `int()`, `float()`, `str()`:
#
# > **Read more:** [W3Schools - Python Data Types](https://www.w3schools.com/python/python_datatypes.asp)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." height="350" />

# %%
print(int(reading_1) + int(reading_2))
# Out:
# 8

# %%
print(str(5) + str(3))
# Out:
# 53

# %% [markdown]
# ## Connecting types to materials data
#
# The three kinds of materials data from earlier map directly onto Python types:
#
# * counts → `int`
# * measurements → `float`
# * labels → `str`

# %% [markdown]
# ### [Check your understanding]
#
# Which Python type (`int`, `float`, or `str`)?
# * Atomic number of an element
# * Molar mass (g/mol)
# * Element symbol (e.g. "Fe")
# * Melting point in degrees Celsius

# %% [markdown]
# Categories ("FCC") and free text ("Sample prepared at 1200°C...") both use `str`.
# Python treats them identically. They behave very differently in analysis.
#
# One more type worth knowing: `bool` stores `True` or `False`. This comes up when you ask
# questions about data, like "is this sample above the melting point?"

# %%
print(type(True))
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ## Units
#
# `8.96` could be density in g/cm³ or length in meters. Python does not know the difference.
# Software enforces **syntax** (valid code), not **physical meaning** (correct science).
# Keeping track of units is your responsibility.

# %%
# density in g/cm^3
density_g_per_cm3 = 8.96

# convert to kg/m^3 (multiply by 1000)
density_kg_per_m3 = density_g_per_cm3 * 1000
print(density_kg_per_m3)
# Out:
# 8960.0

# %% [markdown]
# Descriptive variable names (`density_g_per_cm3`, not `x`) and comments keep track of units.
# Libraries like Pint can automate unit-aware calculations in larger programs.

# %% [markdown]
# # Arithmetic operators

# %% [markdown]
# | operator | meaning | example | result |
# |---|---|---|---|
# | `+` | addition | `4 + 3` | `7` |
# | `-` | subtraction | `4 - 3` | `1` |
# | `*` | multiplication | `4 * 3` | `12` |
# | `/` | division | `4 / 3` | `1.333...` |
# | `**` | exponent | `4 ** 3` | `64` |

# %%
mass_g = 44.5
volume_mL = 5.0
density_g_per_mL = mass_g / volume_mL
print(density_g_per_mL)
# Out:
# 8.9

# %% [markdown]
# ## `**` vs `^`
#
# Some operators use two characters. `**` means exponent, `!=` means not-equal.
#
# **Powers are `**`, never `^`:**

# %%
print(2 ** 3)
# Out:
# 8

# %%
print(2 ^ 3)
# Out:
# 1

# %% [markdown]
# `2 ** 3` → 8. `2 ^ 3` → 1 (bitwise XOR). **No error**, Python thinks you meant it.

# %% [markdown]
# ## Order of operations
#
# Same as algebra: parentheses first, then exponents, then `*`/`/`, then `+`/`-`.
#
# When in doubt, add parentheses. They make the code clearer even when they are not strictly needed:

# %%
mass_g = 44.5
volume_mL = 5.0
print(mass_g / volume_mL + 1)
print(mass_g / (volume_mL + 1))
# Out:
# 9.9
# 7.416666666666667

# %% [markdown]
# Breaking a long calculation into named intermediate steps makes it easier to read and debug:

# %%
mass_g = 44.5
volume_mL = 5.0
adjusted_volume_mL = volume_mL + 1
adjusted_density = mass_g / adjusted_volume_mL
print(adjusted_density)
# Out:
# 7.416666666666667

# %% [markdown]
# Spaces around operators are optional but make code easier to read. `mass_g/volume_mL` and `mass_g / volume_mL` do the same thing. Convention: add spaces around `+`, `-`, `*`, `/`, `=`.

# %% [markdown]
# ### [Check your understanding]
#
# In the code cell below, compute the volume of a sphere with radius `r = 3` cm using $V = \frac{4}{3}\pi r^3$. Use `3.14159` for $\pi$:

# %% [markdown]
# ## Scientific notation
#
# Python uses `e` notation for powers of ten. This also produces a `float`:
#
# | Written form | Python | Value |
# |---|---|---|
# | $3 \times 10^{8}$ | `3e8` | 300000000.0 |
# | $1.6 \times 10^{-19}$ | `1.6e-19` | 0.00000000000000000016 |
# | $6.022 \times 10^{23}$ | `6.022e23` | 602200000000000000000000.0 |
# | $17 \times 10^{-6}$ | `17e-6` | 0.000017 |

# %%
print(1e-6)
print(type(1e-6))
print(6.022e23)
# Out:
# 1e-06
# <class 'float'>
# 6.022e+23

# %% [markdown]
# ## Worked example: thermal expansion
#
# * A 1 m steel rod: $L_0 = 1.000$ m, $\alpha = 17 \times 10^{-6}$ /°C (steel), $\Delta T = 80$ °C
# * $\Delta L = L_0 \, \alpha \, \Delta T$

# %%
L0 = 1.000
alpha = 17e-6
delta_T = 80

# %% [markdown]
# `17e-6` is Python's scientific notation for $17 \times 10^{-6}$

# %%
delta_L = L0 * alpha * delta_T
print(delta_L)
# Out:
# 0.00136

# %% [markdown]
# # `print()` and f-strings

# %% [markdown]
# Last line of a cell auto-displays. For anything else, use `print()`:

# %%
density_g_per_mL
# Out:
# 8.9

# %%
mass_g = 44.5
volume_mL = 5.0
density_g_per_mL   # does NOT display -- not the last line
print(mass_g)
print(volume_mL)
# Out:
# 44.5
# 5.0

# %% [markdown]
# **f-strings** - put `f` before the quote, `{}` around variables:

# %%
print(f"The density is {density_g_per_mL} g/mL")
# Out:
# The density is 8.9 g/mL

# %%
print(f"A sample with mass {mass_g} g and volume {volume_mL} mL has density {mass_g / volume_mL} g/mL")
# Out:
# A sample with mass 44.5 g and volume 5.0 mL has density 8.9 g/mL

# %% [markdown]
# ## Formatting numbers
#
# To round the output, add `:.2f` inside the braces (2 decimal places):

# %%
density_g_per_mL = mass_g / volume_mL
print(f"The density is {density_g_per_mL:.2f} g/mL")
# Out:
# The density is 8.90 g/mL

# %% [markdown]
# ### [Check your understanding]
#
# In the code cell below:
# * Define variables for the mass (40.5 g) and volume (15.0 mL) of an aluminum sample
# * Compute the density
# * Print the density as a labeled f-string, rounded to 2 decimal places
# * Convert to kg/m³ and print as a second labeled f-string

# %% [markdown]
# ## Commenting your code
#
# We introduced `#` comments earlier. Good practice: explain **why**, not **what**:

# %%
# convert density from g/mL to kg/m^3 for the report
density_kg_per_m3 = density_g_per_mL * 1000

# %% [markdown]
# ## Full example with f-strings
#
# Putting it together (same 1 m steel rod as above):

# %%
L0 = 1.000
alpha = 17e-6
delta_T = 80

delta_L = L0 * alpha * delta_T

print(f"Starting length: {L0:.3f} m")
print(f"Temperature change: {delta_T} degC")
print(f"Change in length: {delta_L:.6f} m")
print(f"Final length: {L0 + delta_L:.6f} m")
# Out:
# Starting length: 1.000 m
# Temperature change: 80 degC
# Change in length: 0.001360 m
# Final length: 1.001360 m

# %% [markdown]
# ## Hands-on: theoretical density from the unit cell
#
# The theoretical density of a crystal comes from its unit cell:
#
# $$\rho = \frac{n A}{V_c N_A}$$
#
# where $n$ is the number of atoms per unit cell, $A$ is the atomic weight (g/mol),
# $V_c$ is the unit cell volume (cm³), and $N_A$ is Avogadro's number.

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." height="350" />

# %% [markdown]
# Copper is FCC:
#
# | quantity | value |
# |---|---|
# | $n$ (atoms/cell) | 4 |
# | $a$ (lattice parameter) | 0.36149 nm |
# | $A$ (atomic weight) | 63.55 g/mol |
# | $N_A$ | 6.022e23 /mol |
# | handbook density | 8.96 g/cm³ |
#
# The lattice parameter is in nm, but the density formula needs cm: 1 nm = $10^{-7}$ cm.

# %% [markdown]
# In the code cell below:
#
# 1. Define variables for `n`, `a_nm`, `A`, `N_A`, and the handbook density
# 2. Convert `a_nm` to `a_cm`
# 3. Compute the unit cell volume `V_c = a_cm ** 3`
# 4. Compute `rho`

# %% [markdown]
# Print your computed density as a labeled f-string, rounded to 2 decimal places.
# Then compute the percent error relative to the handbook value:
#
# $$\text{percent error} = \frac{\rho_{\text{computed}} - \rho_{\text{handbook}}}{\rho_{\text{handbook}}} \times 100$$

# %% [markdown]
# Try the same calculation for Fe: BCC, `n` = 2, `a` = 0.28665 nm, `A` = 55.85 g/mol,
# handbook density 7.874 g/cm³.

# %% [markdown]
# # Reading error messages

# %% [markdown]
# Errors are normal. **Strategy: read the last line first.**

# %% [markdown]
# ## `NameError`

# %%
# EXPECTED-ERROR: this cell intentionally fails
density = 8.9
print(denisty)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 # EXPECTED-ERROR: this cell intentionally fails
#       2 density = 8.9
# ----> 3 print(denisty)
#
# NameError: name 'denisty' is not defined

# %% [markdown]
# `name 'denisty' is not defined` - misspelled. The variable is `density`.

# %% [markdown]
# ## `TypeError`

# %%
# EXPECTED-ERROR: this cell intentionally fails
'5' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # EXPECTED-ERROR: this cell intentionally fails
# ----> 2 '5' + 5
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# `can only concatenate str (not "int") to str` - fix with `int('5') + 5`
#
# You already saw `SyntaxError` earlier when `mass g = 44.5` failed because of the space.
# That error appears whenever Python cannot parse your code at all.
#
# > **Read more:** [Python docs - Errors and Exceptions](https://docs.python.org/3/tutorial/errors.html)

# %% [markdown]
# ## Saving your work
#
# * Colab autosaves to Google Drive
# * To submit assignments: **File → Download → Download .ipynb**, then upload the `.ipynb` file to Canvas

# %% [markdown]
# ## Further reading
#
# - [w3schools: Python variables](https://www.w3schools.com/python/python_variables.asp)
# - [w3schools: Python operators](https://www.w3schools.com/python/python_operators.asp)
# - [w3schools: Python strings](https://www.w3schools.com/python/python_strings.asp)
# - [Software Carpentry: Running and quitting](https://swcarpentry.github.io/python-novice-gapminder/01-run-quit.html)
# - [Software Carpentry: Variables and assignment](https://swcarpentry.github.io/python-novice-gapminder/02-variables.html)
