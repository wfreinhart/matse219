# %% [markdown]
# # Homework 2: Selecting and summarizing materials data

# %% [markdown]
# Covers **Lecture 3** (arrays, elementwise arithmetic, broadcasting, and indexing),
# **Lecture 4** (slicing, fancy indexing, `.shape`, and `axis`), and **Lecture 5**
# (descriptive statistics).

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# The `ipynb` file type is the only accepted format.
#
# Save a copy before beginning. Reloading or disconnecting can revert the notebook to the
# instructor copy.

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Problem 1 (20 pts): Vector arithmetic and slicing
#
# A load frame measures the force required to fracture a material sample. Cross-sectional area is measured on a different
# instrument. You are evaluating six tensile specimens measured by each instrument. Load is reported in kN, area in mm$^2$.

# %%
import numpy as np

max_load = np.array([31.2, 28.2, 35.8, 30.1, 34.0, 29.4]) # kN
area = np.array([62.4, 57.0, 70.2, 61.6, 67.2, 59.4])     # mm^2

# %% [markdown]
# (a) Convert the whole `max_load` array to newtons (N) and print it.
#
# > Note the lack of units! These are plain numbers, so keeping track of units is your job.
#
# (b) Compute the ultimate tensile strength (UTS) of every specimen:
#
# $$\mathrm{UTS} = \frac{\mathrm{maximum\ load\ (N)}}{\mathrm{area\ (mm^2)}}.$$
#
# Print the whole array.
#
# > $1\ \mathrm{N/mm^2}=1\ \mathrm{MPa}$, so the result is in MPa.
#
# (c) Print the minimum and maximum UTS as labeled f-strings rounded to 2 decimal places.
#
# (d) Specimens 0, 1, and 2 were cut from one rolled plate; specimens 3, 4, and 5 came from
# a second plate. Use a slice operator to combine each plate's three strengths into two different arrays and
# print both.
#
# (e) Which plate would you rather build a component from, and why?

# %%
# your code here

# %% [markdown]
# # Problem 2 (25 pts): Indexing and slicing
#
# Position in the periodic table corresponds to chemistry. A row is a period and a column
# is a group, so selecting one selects a chemical family.
#
# Run the next cell for five parallel arrays from the Lectures 3-4 periodic table data.
# All five are ordered by atomic number, so position `i` is the same element in each.

# %%
#@title Load the real periodic-table dataset (click ▶ to run, data loading, not a learning objective) { display-mode: "form" }
import os

import numpy as np
import pandas as pd

_file = 'mendeleev_elements.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}',
                 f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    _table = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e

symbol = _table['symbol'].to_numpy()
atomic_number = _table['atomic_number'].to_numpy()
radius_pm = _table['covalent_radius_cordero'].to_numpy()
density = _table['density'].to_numpy()
atomic_weight = _table['atomic_weight'].to_numpy()

print(f'Loaded {len(symbol)} elements from {_file}')
# Out:
# Loaded 118 elements from mendeleev_elements.csv

# %% [markdown]
# (a) Sulfur has atomic number 16. Print its symbol, atomic number, atomic weight, and
# density by indexing the arrays.
#
# (b) Use a negative index to print the symbol and atomic number for Sulfur.
#
# (c) Period 3 runs from sodium (atomic number 11) through argon (atomic number 18).
# Use slicing to print the symbols and atomic weights for the whole period.
#
# (d) Print the symbols and covalent radii of group 2 (Be, Mg, Ca, Sr, Ba, Ra) using fancy indexing.
#
# > Group 2 is a column, so you can't slice it.
#
# (e) Suppose `atomic_weight` had been sorted from smallest to largest while `symbol` stayed
# in atomic-number order. Explain the problem with subsequent analysis. How would you fix or avoid it?
#
# (f) Discuss the trend in the group-2 radii you printed in part (d). *(1-2 sentences)*

# %%
# your code here

# %% [markdown]
# # Problem 3 (30 pts): Array shape, 2-D indexing, and axis
#
# Quenching doesn't cool a plate evenly. The edges lose heat on two sides, while the middle has
# only one way out. This leads to distributions of properties across the plate rather than being uniform.
#
# A lab ran three hardness scans across a heat-treated plate. Each row is one scan.
# Each column is the same location, left edge to right edge. Values are Rockwell C (HRC).

# %%
hardness_map = np.array([
    [59.8, 59.0, 58.2, 58.0, 58.9, 59.7],
    [59.5, 58.8, 57.9, 57.8, 58.7, 59.4],
    [59.9, 59.1, 58.1, 57.9, 59.0, 59.8],
])

# %% [markdown]
# (a) Print the array's shape. Describe what each of the two numbers means for this experiment. *(1-2 sentences)*
#
# > Answer in scans and location, not rows and columns.
#
# (b) Using 2D indexing, print the fourth location in the second scan.
# Then print the last reading in the last scan using negative indices for both.
#
# (c) Use `:` to print the whole first scan, then the third location across all three scans.
#
# (d) Compute and print `np.mean(hardness_map, axis=0)` and `np.mean(hardness_map, axis=1)`, and report the `.shape` of each result.
#
# (e) You want to know whether the center of the plate came out softer than the edges. Indicate
# which of the two averages from part (d) you would use to assess this.
#
# > Verify that your answer makes sense!

# %%
# your code here

# %% [markdown]
# # Problem 4 (25 pts): Descriptive statistics
#
# A supplier quotes you the same yield strength for two heat-treatment lots. It's an
# average, and two lots with the same average can behave quite differently.
#
# There are ten coupons from each lot. The yield strengths are in MPa.

# %%
lot_A = np.array([508, 511, 509, 512, 510, 507, 513, 509, 511, 510])
lot_B = np.array([470, 550, 485, 535, 500, 520, 495, 525, 480, 540])

# %% [markdown]
# (a) For each lot, use NumPy functions to compute and print the mean, median, and standard
# deviation. Label every number and round to 2 decimal places.
#
# (b) The two lots have the same mean and the same median. One of them you'd accept and one
# you'd reject. Which is more consistent and why?
# What quantity could you add to part (a) to make the case stronger?
#
# (c) Work out the population variance and population standard deviation of `lot_A` by hand:
# - the mean,
# - the deviations from it,
# - the squared deviations,
# - their sum divided by `len(lot_A)`,
# - and the square root.
#
# Confirm your numbers match the ones you get with NumPy.
#
# > Don't call `np.var` or `np.std` until that last step!
#
# (d) Sort `lot_B` with `np.sort`. Compute its median by hand and confirm it matches the result from part (a).

# %%
# your code here
