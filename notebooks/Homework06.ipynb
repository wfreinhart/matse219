# %% [markdown]
# # Homework 6: loops and conditionals

# %% [markdown]
# Covers **Lecture 15** (`for` loops, `range`, `if` / `elif` / `else`, counters and records).

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# The `ipynb` file type is the only accepted format.
#
# Save a copy before beginning.
# Reloading or disconnecting can revert the notebook to the instructor copy.

# %% [markdown]
# # Problem 0 (-10 pts if blank): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work. Critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Dataset
#
# A rotating shaft may survive one load and still fail after that load is repeated millions of times.
# You are the designer, and you have to pick a stress amplitude your part survives for its whole service life.
#
# Run the cell below for the campaign from Lecture 15: seventeen specimens of 42CrMo4 steel, each cycled at one stress amplitude until it broke or until the test was stopped.
# Stress amplitude measures how far the repeated load swings from its mean, rather than the largest stress reached in a cycle.

# %%
#@title Load one S-N fatigue campaign (click ▶ to run, data loading, not a learning objective) { display-mode: "form" }
import os

import pandas as pd

_file = 'fatigue_42crmo4.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}',
                 f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    _table = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e

_curve = _table[_table['curve_id'] == 29].sort_values('stress_amplitude_MPa', ascending=False)

stress = _curve['stress_amplitude_MPa'].tolist()
cycles = _curve['cycles'].tolist()
runout = _curve['is_runout'].tolist()

print(f'Loaded one fatigue campaign on 42CrMo4 steel: {len(stress)} specimens')
print(f'  stress: {min(stress):.0f} to {max(stress):.0f} MPa')
print(f'  cycles: {min(cycles)} to {max(cycles)}')
print(f'  runout: {sum(runout)} specimen(s) never broke')
# Out:
# Loaded one fatigue campaign on 42CrMo4 steel: 17 specimens
#   stress: 350 to 675 MPa
#   cycles: 6775 to 33608010
#   runout: 1 specimen(s) never broke

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# You have three parallel lists.
#
# - `stress` is the amplitude each specimen was cycled at, in MPa
# - `cycles` is how many cycles it lasted
# - `runout` is `True` for a specimen that had not broken when the test was stopped
#
# Across the four problems you will read those lists one specimen at a time, classify the specimens by stress, repackage them as records, and finish with a chart for a design review.
#
# > Position `i` is the same specimen in all three lists, so `stress[4]`, `cycles[4]` and `runout[4]` describe one test.

# %% [markdown]
# # Problem 1 (25 pts): `for` loops over parallel lists

# %% [markdown]
# (a) Print every stress amplitude.
#
# - Loop over `stress` and print each value with the unit `MPa` beside it.

# %%
# your code here

# %% [markdown]
# (b) Print each specimen's stress beside the life it produced.
#
# - Loop with `range(len(stress))` and print the stress and the cycles for each specimen on one line.

# %%
# your code here

# %% [markdown]
# (c) Count the specimens tested at 450 MPa or below.
#
# - Set a counter to zero before the loop, then use an `if` inside it to add to the counter.

# %%
# your code here

# %% [markdown]
# (d) Print the counter.

# %%
# your code here

# %% [markdown]
# (e) In one sentence, say why part (b) needed `range(len(stress))` when part (a) did not.

# %% [markdown]
# *your answer here*

# %% [markdown]
# # Problem 2 (30 pts): `if` / `elif` / `else` to label each specimen

# %% [markdown]
# Lecture 15 split the campaign by how long each specimen lasted.
# Your datasheet wants the other split, by the stress each specimen was tested at.
#
# Use these three bands:
#
# - `'high'` for a stress amplitude above 600 MPa
# - `'medium'` for a stress amplitude above 425 MPa
# - `'low'` for everything else
#
# > These boundaries are conventions chosen for this assignment, not properties of the steel.

# %% [markdown]
# (a) Build an empty list called `bands`.

# %%
# your code here

# %% [markdown]
# (b) Fill it with one label per specimen.
#
# - Loop over `stress`, choose the label with an `if` / `elif` / `else` chain, and append it to `bands`.
#
# > Your three bands have to cover every specimen and must never overlap.

# %%
# your code here

# %% [markdown]
# (c) Print `len(bands)`.
#
# > It should come out equal to `len(stress)`. If it does not, the `append` is in the wrong place.

# %%
# your code here

# %% [markdown]
# (d) Show the labels against the data they came from.
#
# - Loop with `range(len(stress))` and print each specimen's stress beside its band.

# %%
# your code here

# %% [markdown]
# (e) Count how many specimens landed in the `'low'` band.
#
# - Use a counter and an `if`, looping over `bands`.

# %%
# your code here

# %% [markdown]
# (f) In one or two sentences, say what would change if you tested for `'medium'` before `'high'` in your chain, and why.

# %% [markdown]
# *your answer here*

# %% [markdown]
# # Problem 3 (25 pts): records, and the same question two ways

# %% [markdown]
# Your three parallel lists stay correct only as long as nobody sorts one of them.
# A list of records keeps each specimen's numbers with their labels, so you cannot fall out of step.
#
# > `.append()` adds one entry to the end of a list, so start from an empty one.

# %% [markdown]
# (a) Build an empty list called `specimens`.

# %%
# your code here

# %% [markdown]
# (b) Fill it with one dictionary per specimen.
#
# - Loop with `range(len(stress))` and append a dictionary with the keys `'stress'`, `'cycles'` and `'runout'`.

# %%
# your code here

# %% [markdown]
# (c) Print the first entry of `specimens`.

# %%
# your code here

# %% [markdown]
# (d) Print the stress of every specimen that lasted fewer than 100000 cycles.
#
# - Loop over `specimens` and use an `if` on each record.

# %%
# your code here

# %% [markdown]
# (e) Count those same specimens a second way, with a mask.
#
# - Build the mask from `cycles` and print the count with `np.sum`.
#
# > Comparing a plain list to a number raises a `TypeError`, so the mask needs `np.array(...)` around `cycles` first.

# %%
# your code here

# %% [markdown]
# (f) In one or two sentences, name something the loop in (d) can do that the mask in (e) cannot.

# %% [markdown]
# *your answer here*

# %% [markdown]
# # Problem 4 (20 pts): the stress-life chart

# %% [markdown]
# This is the figure the campaign was run to produce.
# Every specimen is one point, and you have to draw the runout differently, because its cycle count is a lower bound rather than a life.
#
# > The runout never broke. Drawing it like the others would claim the steel fails at that number, when all the test shows is that it survives at least that long.

# %% [markdown]
# (a) Plot stress amplitude against cycles, one point per specimen.
#
# - Make a `fig, ax`, then loop with `range(len(stress))` and use an `if` / `else` so the runout gets a different marker from the specimens that broke.

# %%
# your code here

# %% [markdown]
# (b) Label both axes with the quantity and its unit.

# %%
# your code here

# %% [markdown]
# (c) Put the cycles axis on a log scale with `ax.set_xscale('log')`.
#
# > The lives in this campaign span four orders of magnitude, so a linear axis crushes most of them against the left edge.

# %%
# your code here

# %% [markdown]
# (d) In two or three sentences, answer both:
#
# - What is the highest tested stress at which a specimen survived at least ten million cycles?
# - Why is that one result not enough to set a design limit for a shaft?

# %% [markdown]
# *your answer here*

# %% [markdown]
# # Wrap-up
#
# This assignment used three loop patterns from Lecture 15.
# A direct loop handled one list, `range(len(...))` kept parallel lists aligned, and a loop over records kept each specimen's label next to its numbers.
# Counters accumulated totals, while `if` / `elif` / `else` chose different work for different specimens.
#
# The mask in Problem 3 was shorter for counting one condition.
# The loop in Problem 4 was the better tool when one specimen needed a different marker and a different interpretation.
# Choosing between those approaches is part of the analysis: use a mask to select, and use a loop when each item needs its own action.
