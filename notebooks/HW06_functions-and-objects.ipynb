# %% [markdown]
# # Homework 6: Functions and Objects

# %% [markdown]
# This homework covers two lectures:
# * **Lecture 14** (functions and scope) -- Problems 1-3
# * **Lecture 15** (objects and classes, consuming not writing) -- Problems 4-5
#
# Two datasets, both already familiar from lecture:
# * `dataset_elements` -- 52 elements with atomic-scale computed properties (Lecture 8, reused in
#   Lecture 14)
# * `dataset_steels` -- 915 steel alloys with composition and mechanical properties (Lecture 15)

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# *Only* the `ipynb` file type will be accepted.
#
# Save a copy of the notebook right away to avoid losing your work!

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# ## Data file for Problems 1-3
#
# Run this code cell to load the same elemental-properties table from Lecture 14.

# %% [markdown]
# ## Dataset: Elemental Properties
#
# This dataset contains physical and electronic properties of chemical elements,
# including atomic mass, ionization energies, vacancy formation energies,
# bulk static energies, and crystal structures.
#
# Note that some entries contain `NaN` (Not a Number) values where data was
# unavailable. We'll need to handle these when performing calculations.

# %%
import os
import pandas as pd

_file = 'elements.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}', f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    data = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e
data
# Out:
#    Symbol  Bulk Static Energy (eV)  Reference Energy (eV)  Clean Cohesive  \
# 0      Ac              -442.228190                  -0.25             1.0
# 1      Ag              -305.971040                  -0.35             1.0
# 2      Al              -403.993240                  -0.23             1.0
# 3      Ar                -7.404033                  -0.05             1.0
# 4      Au              -353.846200                  -0.28             1.0
# 5      Ba                      NaN                    NaN             0.0
# 6      Be              -395.309910                  -0.01             1.0
# 7      Ca              -216.424440                  -0.13             1.0
# 8      Cd                      NaN                    NaN             0.0
# 9      Ce              -640.664090                  -1.27             1.0
# 10     Co              -746.519270                  -1.34             1.0
# 11     Cu              -402.331380                  -0.25             1.0
# ...

# %% [markdown]
# # Problem 1 (20 pts): a function with a default argument
#
# (a) Write a function `column_summary(data, col, digits=2)` that:
# * pulls `data[col]`, drops any `NaN`s (some columns in this dataset have real gaps -- see
#   Lecture 8),
# * returns a tuple `(mean, std)`, each rounded to `digits` decimal places (`digits` defaults to
#   `2`),
# * has a one-line docstring describing what it does.
#
# (b) Test `column_summary` on `'Atomic Mass'` twice: once with the default `digits`, and once
# calling it with `digits=4`. Print both results.

# %% [markdown]
# # Problem 2 (20 pts): applying it across columns
#
# Reuse `column_summary` from Problem 1 -- don't rewrite it, just call it.
#
# (a) Build a list called `numeric_cols` containing these four column names: `'Atomic Mass'`,
# `'Ionization Energies (eV)'`, `'Vacancy Formation Energy (eV)'`, and
# `'Bulk Static Energy (eV)'`. (The last one has real `NaN`s -- that's deliberate, to check that
# your function's `.dropna()` actually works.)
#
# (b) Loop over `numeric_cols` and, for each column, call `column_summary` and print the column
# name alongside its `(mean, std)`. You should get sensible numbers for all four columns, including
# `'Bulk Static Energy (eV)'`.
#
# (c) In a comment, explain in one sentence why this loop would have been much more painful to
# write as four separate copy-pasted cells instead of one function called four times.

# %% [markdown]
# # Problem 3 (20 pts): spot the scope bug
#
# Here is a function with the exact same problem as `bad_zscore` from lecture. Run it as-is first:

# %%
cutoff = 3.0

def is_light_element(mass):
    return mass < cutoff

print(is_light_element(2.5))
cutoff = 1.0
print(is_light_element(2.5))   # same call, different answer!
# Out:
# True
# False

# %% [markdown]
# (a) In a comment or short markdown cell, explain **why** `is_light_element(2.5)` gave two
# different answers even though the call itself never changed. Name the specific habit from
# Lecture 14 that would have prevented this.
#
# (b) Rewrite the function as `is_light_element_fixed(mass, cutoff)`, taking `cutoff` as an
# explicit parameter instead of reading it from outside.
#
# (c) Demonstrate that your fixed version is *not* affected by reassigning the outer `cutoff`
# variable: call `is_light_element_fixed(2.5, 3.0)`, then reassign `cutoff = 1.0` again, then call
# `is_light_element_fixed(2.5, 3.0)` a second time with the *same* arguments and show the answer
# doesn't change.

# %% [markdown]
# ## Data file for Problems 4-5
#
# Run this code cell to load the same steel alloy dataset from Lecture 15 -- 915 alloys,
# composition in weight percent, mechanical properties, and an `Alloy family` column.

# %% [markdown]
# ## Dataset: Steel Alloy Compositions and Mechanical Properties
#
# This dataset contains elemental compositions and mechanical properties of 915 steel alloys.
#
# Composition columns (in wt%): `C`, `Si`, `Mn`, `P`, `S`, `Ni`, `Cr`, `Mo`, `Cu`, `V`, `Al`, `N`, `Ceq`, `Nb + Ta`
#
# Target columns: `0.2% Proof Stress (MPa)`, `Tensile Strength (MPa)`, `Elongation (%)`, `Reduction in Area (%)`
#
# The `Alloy code` column contains labels like `A1`, `B3`, etc. We derive `alloy_family` (first letter only)
# to get a small set of categorical labels useful for classification tasks (4 families: C, L, M, V, all >150 samples).

# %%
import os
import pandas as pd

_file = 'steels.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}', f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    data = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e

# derive alloy family label (first letter of alloy code)
data['Alloy family'] = [c[0] for c in data['Alloy code']]

# set up features (composition columns) and target
x = data.loc[:, ' C':'Nb + Ta']
y = data['Alloy family']
alloy_family = data['Alloy family']

print(f'{len(data)} samples, {x.shape[1]} composition features')
data.head()
# Out:
# 915 samples, 14 composition features
#   Alloy code     C    Si    Mn      P      S     Ni    Cr    Mo    Cu  ...  \
# 0        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  ...
# 1        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  ...
# 2        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  ...
# 3        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  ...
# 4        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  ...
#
#       Al       N  Ceq  Nb + Ta   Temperature (°C)   0.2% Proof Stress (MPa)  \
# 0  0.003  0.0066  0.0      0.0                 27                       342
# 1  0.003  0.0066  0.0      0.0                100                       338
# 2  0.003  0.0066  0.0      0.0                200                       337
# 3  0.003  0.0066  0.0      0.0                300                       346
# 4  0.003  0.0066  0.0      0.0                400                       316
#
# ...

# %% [markdown]
# # Problem 4 (20 pts): method discovery with `dir()` and `help()`
#
# (a) Using `[m for m in dir(data[' Tensile Strength (MPa)']) if not m.startswith('__')]` (the
# same filtering idiom from Lecture 15), find the name of the method that returns the *row label*
# (here, the `Alloy code`) of the row holding the maximum value of a `Series` -- it starts with
# `idx`. Confirm what it does with `help()` before using it.
#
# (b) Set `data`'s index to `'Alloy code'` with `data = data.set_index('Alloy code')`, then use the
# method you found in (a) on `data[' Tensile Strength (MPa)']` to report which `Alloy code` has the
# single highest tensile strength in the dataset.
#
# (c) Use `help()` on one more unfamiliar method, `.nunique()`, then call it on
# `data['Alloy family']` to report how many distinct alloy families exist in this dataset.

# %% [markdown]
# # Problem 5 (20 pts): method chaining on the steels data
#
# (a) Write **one** method chain (parenthesized and broken across lines the way Lecture 15 did) on
# `data` that answers: "which alloy family has the highest average `0.2% Proof Stress (MPa)`?" Your
# chain should use `.groupby(...)`, select the target column, `.mean()`, and `.sort_values(...)`.
# (Note: like the tensile strength column in Problem 4, this column name has a leading space in
# the CSV -- `' 0.2% Proof Stress (MPa)'`.)
#
# (b) Write a second chain answering: "which alloy family has the *lowest* average
# `Elongation (%)`?" (Same pattern as (a) -- change the column and the sort direction as needed.
# Same leading-space quirk applies: `' Elongation (%)'`.)
#
# (c) In one sentence, name one advantage of writing these as a single chained expression instead
# of three separate intermediate variables.

# %% [markdown]
# # Wrap-up
#
# This homework asked for exactly the two skills from the last two lectures: writing and reusing a
# small function with a default argument and a docstring (Lecture 14), and discovering + chaining
# `DataFrame`/`Series` methods you weren't explicitly taught (Lecture 15). If you found yourself
# copy-pasting a block of code with only one number changed, or hard-coding a value a function
# should have taken as a parameter, that's the signal to stop and refactor -- exactly the judgment
# call both lectures were building toward.
