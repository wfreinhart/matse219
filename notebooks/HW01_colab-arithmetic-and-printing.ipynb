# %% [markdown]
# # Homework 1: Colab setup, variables, arithmetic, and printing

# %% [markdown]
# This homework covers **Lecture 1** (Python basics: variables, arithmetic, printing): Colab
# account setup, running and modifying a notebook cell, variables and types, arithmetic
# operators, comments, and f-strings.
#
# No libraries are used anywhere in this homework -- everything is bare Python, exactly like
# Lecture 1.

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# *Only* the `ipynb` file type will be accepted.
#
# Save a copy of the notebook right away to avoid losing your work!

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Problem 1 (15 pts) -- Colab setup and your first modification
#
# (a) In the markdown cell below, replace the placeholder text with your name and your Penn
# State email address, to confirm you're set up on Colab under your PSU Google account.

# %% [markdown]
# *your name and PSU email here*

# %% [markdown]
# (b) Run the code cell below exactly as written (`Shift + Enter`), top to bottom, and confirm
# you see the printed output.

# %%
sample_name = "REPLACE_WITH_YOUR_NAME"
print(f"Notebook owner: {sample_name}")
# Out:
# Notebook owner: REPLACE_WITH_YOUR_NAME

# %% [markdown]
# (c) Now **modify** the cell above: change the string assigned to `sample_name` so it prints
# your own name instead of the placeholder, then re-run it. Confirm the new output looks right
# before moving on -- this is the "run and modify a provided cell" exercise Lecture 1 promised.

# %% [markdown]
# # Problem 2 (40 pts) -- Density calculations
#
# For each part, define named variables for every given quantity (don't just type raw numbers
# into the formula), compute the requested result, and print it with a labeled f-string using
# `:.2f` (or the format specified). Use `**`, never `^`, for any powers you need.
#
# (a) A machined aluminum bracket has mass `54.0` g and volume `20.0` mL (1 mL = 1 cm$^3$).
# Compute its density in g/mL and print it labeled, rounded to 2 decimal places. (Sanity check:
# aluminum's real density is about 2.70 g/cm$^3$ -- your answer should land right on that.)
#
# (b) A titanium pin has mass `90.2` g and volume `20.0` mL. Compute and print its density the
# same way. (Sanity check: titanium's real density is about 4.51 g/cm$^3$.)
#
# (c) Convert *both* densities from (a) and (b) to kg/m$^3$ (multiply by `1000`, exactly like
# Lecture 1's copper example) and print each, labeled, rounded to 1 decimal place.
#
# (d) A steel bracket has density `7.85` g/cm$^3$ (typical for mild steel) and volume `250.0`
# cm$^3$. This time you're given density and volume and asked for **mass** -- rearrange the
# density formula ($\text{density} = \text{mass}/\text{volume}$, so
# $\text{mass} = \text{density} \times \text{volume}$) and print the resulting mass in grams,
# rounded to 1 decimal place.

# %% [markdown]
# ### (a) Aluminum bracket density

# %%
# your code here

# %% [markdown]
# ### (b) Titanium pin density

# %%
# your code here

# %% [markdown]
# ### (c) Convert both densities to kg/m^3

# %%
# your code here

# %% [markdown]
# ### (d) Steel bracket mass (rearranged formula)

# %%
# your code here

# %% [markdown]
# # Problem 3 (45 pts) -- Unit conversions and a thermal-expansion report
#
# (a) An aluminum rod has initial length $L_0 = 2.000$ m and linear thermal expansion
# coefficient $\alpha = 23 \times 10^{-6}\ /°C$ (aluminum's real value -- use scientific
# notation, `23e-6`, exactly like Lecture 1's `17e-6`). It's heated by $\Delta T = 60$ °C. Using
# $\Delta L = L_0\,\alpha\,\Delta T$, build a narrated report with four separate `print()`
# f-string lines, matching Lecture 1's "full example, narrated" template:
# * starting length (3 decimal places)
# * temperature change (no decimals needed)
# * change in length (6 decimal places -- this is a small number, so extra digits matter)
# * final length, `L0 + delta_L` (6 decimal places)
#
# (b) A **change** in temperature of 60 °C (from part (a)) is *not* the same conversion as an
# absolute temperature reading -- there's no `+ 32` involved when you're converting a
# *difference*. The correct conversion for a temperature *change* is
# $\Delta T_{°F} = \Delta T_{°C} \times \tfrac{9}{5}$. Compute and print, labeled, the
# Fahrenheit-degree equivalent of the 60 °C change from part (a).
#
# (c) A sample has mass `250.0` g. Using the conversion factor `1 lb = 453.592 g`, convert its
# mass to pounds and print it labeled, rounded to 4 decimal places.

# %% [markdown]
# ### (a) Thermal expansion of the aluminum rod

# %%
# your code here

# %% [markdown]
# ### (b) Temperature-change conversion, °C to °F

# %%
# your code here

# %% [markdown]
# ### (c) Mass conversion, g to lb

# %%
# your code here

# %% [markdown]
# # Wrap-up
#
# Everything in this homework -- variables, `int`/`float`/`str`, `**` for powers, comments, and
# f-strings with `:.2f`-style formatting -- is exactly what Lecture 1 covered, with zero
# libraries imported. If a result doesn't look physically reasonable (a density nowhere near a
# real metal, a rod that shrinks instead of expands), that's Lecture 1's warning about Python
# happily computing a wrong answer just as fast as a right one -- stop and check your
# parentheses and units before moving on.
