# %% [markdown]
# # Homework 4: pandas, plotting, and derived quantities

# %% [markdown]
# Covers **Lecture 8** (pandas and column types), **Lecture 9** (basic plots),
# and **Lecture 10** (additional pandas, pyplot, and numpy).

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# The `ipynb` file type is the only accepted format.
#
# Save a copy before beginning. Reloading or disconnecting can revert the notebook to the
# instructor copy.

# %% [markdown]
# # Problem 0 (-10 pts if blank): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work. Critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# Dataset
#
# A [fused-deposition](https://en.wikipedia.org/wiki/Fused_filament_fabrication) printer has a dozen settings, and every part that comes off it has a
# surface finish and a strength. A student ran 50 prints at different settings and measured both outcomes.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/ad/RepRap_printing_closeup.jpg/960px-RepRap_printing_closeup.jpg" alt="Close-up of a fused-deposition printer in operation, with a brass nozzle above three red parts whose deposited layers are visible" width=520/>
#
# Photo by Emmanuel Gilloz,
# [CC BY 2.0](https://creativecommons.org/licenses/by/2.0/),
# [via Wikimedia Commons](https://commons.wikimedia.org/wiki/File:RepRap_printing_closeup.jpg).

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="600" />

# %% [markdown]
# Each pass of the nozzle leaves one bead. `layer_height (mm)` is the height of a single
# bead, and `roughness (microns)` measures the steps those beads leave on the side wall.
# `tension_strength (Mpa)` is the stress the finished part carries before it breaks.
#
# Most of this assignment works one question: which settings produce a strong part, and
# what do you give up elsewhere for that strength?
#
# > The measurements are from Ahmet Okudan's [3D printer dataset](https://github.com/ahmetokudan/3dprinterdeeplearning), released for unrestricted use.

# %% [markdown]
# # Problem 1 (20 pts): Investigating a DataFrame

# %% [markdown]
# The file records 12 columns for each of the 50 prints.
#
# Most of them are process settings you'd dial in before printing, like layer height and
# infill density.
#
# Two are measured afterward: the surface roughness and the tensile strength you got.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/3dprinting.csv'

# %% [markdown]
# (a) Read `url` into a DataFrame called `prints` with `pd.read_csv`.
#
# - Print its shape.
# - In a comment, say which number in the shape is the number of prints.
#
# > The column names already carry their units, e.g. `layer_height (mm)`. Keep that suffix
# > when you refer to a column by name.

# %%
# your code here

# %% [markdown]
# (b) Look at what you loaded.
#
# - Show the first five rows.
# - Print the column names.

# %%
# your code here

# %% [markdown]
# (c) Print the column types with `.dtypes`.
#
# Two of them come back as `object` rather than as a number.
#
# - Name those two in a comment.
# - Say whether you would have expected them to be `object`, `int`, or `float`.
#
# > Recall: `object` here means whatever Python couldn't convert the entire column to a numeric type.

# %%
# your code here

# %% [markdown]
# (d) Count the entries in the two text columns.
#
# - Print the counts of each `material` with `.value_counts()`.
# - Print the counts of each `infill_pattern` with `.value_counts()`.
# - Comment on what this tells you about the nature of these columns (are they free text? categorical? boolean?). How did you determine this? (1-2 sentences)

# %%
# your code here

# %% [markdown]
# # Problem 2 (30 pts): Plotting the DataFrame

# %% [markdown]
# Two of the columns are outcomes (response variables): `roughness (microns)` and `tension_strength (Mpa)` *(note the capitalization!)*.
#
# The rest are settings you could change on your print (design variables).

# %% [markdown]
# (a) Plot layer height against roughness.
#
# - Plot `layer_height (mm)` and `roughness (microns)` against each other with an appropriate chart type.
# > You could convert them to arrays or use Series
# - Label both axes.
# - Set the marker color with `color=`.

# %%
# your code here

# %% [markdown]
# (b) In 2-3 sentences, answer both:
#
# - What does the figure show about thicker layers?
# - Does the figure establish that layer height setting *causes* this effect?

# %% [markdown]
# *your answer here*

# %% [markdown]
# (c) A printer has two heaters, and both are measured in degrees Celsius, so both can go on the same axes.
#
# Draw one figure with `roughness (microns)` against both temperatures.
#
# - Use one `ax.scatter` call for `nozzle_temperature (degC)`.
# - Use one `ax.scatter` call for `bed_temperature (degC)`.
# - Call `ax.legend()`.
#
# > Make sure to label both axes so `ax.legend()` shows them.

# %%
# your code here

# %% [markdown]
# (d) In 2-3 sentences:
#
# - Which of the two temperatures looks more related to roughness?
# - What information in the figure are you using to determine that?

# %% [markdown]
# *your answer here*

# %% [markdown]
# (e) Plot a histogram of `tension_strength (Mpa)`.
#
# - Use `ax.hist`.
# - Pass a bin count with `bins=` (choose a good number).
# - Label both axes.
#
# > Recall: we had a heuristic for choosing number of bins.

# %%
# your code here

# %% [markdown]
# # Problem 3 (30 pts): A derived column

# %% [markdown]
# A strong part with a rough surface is not obviously better than a weaker part with a smooth one.
#
# Taking the quotient gives a scalar number that describes the trade-off: the strength you get per micron of roughness you accept.

# %% [markdown]
# (a) Compute that number for every print using elementwise arithmetic.
#
# - Divide `tension_strength (Mpa)` by `roughness (microns)`.
# - Store the result in `prints` under the name `strength_per_micron`.
# - Show the first five rows of `prints`.

# %%
# your code here

# %% [markdown]
# (b) Plot the new column against `layer_height (mm)`.
#
# - Use `ax.scatter`.
# - Label both axes.

# %%
# your code here

# %% [markdown]
# (c) Narrow the view onto the thinnest layers.
#
# - Redraw the same figure.
# - Set the x axis to run from 0 to 0.1 mm with `ax.set_xlim`.
#
# > `ax.set_xlim` changes the window onto the data. Nothing is recomputed, and no points
# > are dropped from the table.

# %%
# your code here

# %% [markdown]
# (d) In 2-3 sentences, answer both:
#
# - Which layer heights give the most strength per micron of roughness?
# - Name one other setting in the table you would hold fixed before trusting that
#   comparison.

# %% [markdown]
# *your answer here*

# %% [markdown]
# # Problem 4 (20 pts): `np.linspace`, `np.exp`, and two panels

# %% [markdown]
# This problem does not use the printer data at all. You'll generate every value yourself
# with `numpy`.

# %% [markdown]
# (a) Build the $x$ values for this problem.
#
# - Create a linearly spaced array of floats from -10.0 to +10.0 using `np.linspace`.
# - Print its length.

# %%
# your code here

# %% [markdown]
# (b) Assuming the values from part (a) are $x$, calculate the values of
# $y = \exp(\frac{-x^2}{4\pi})$ using `np.exp`.

# %%
# your code here

# %% [markdown]
# (c) Plot $y$ vs $x$ from parts (a)-(b).
#
# - Use `fig, ax = plt.subplots()` and `ax.plot`.
# - Label both axes.
# - Draw a horizontal line at $y = 0.5$ with `ax.axhline`.

# %%
# your code here

# %% [markdown]
# (d) Put the linear and the logarithmic view of the same curve side by side.
#
# - Call `plt.subplots(1, 2)` and unpack the result as `fig, axes`.
# - Plot $y$ against $x$ in `axes[0]`.
# - Plot $y$ against $x$ in `axes[1]`.
# - Change the y scale of `axes[1]` to logarithmic with `.set_yscale('log')`.
# - Label both axes on both panels.
#
# > Asked for more than one box, `plt.subplots` returns an array of axes rather than a
# > single one. `fig.tight_layout()` keeps the labels of neighboring panels apart.

# %%
# your code here
