# %% [markdown]
# # Homework 2: Selecting and summarizing materials data

# %% [markdown]
# This homework builds on **Lecture 2** (array arithmetic and units) and focuses on
# **Lecture 3** (indexing, slicing, 2D arrays, shape, and axis) and **Lecture 4**
# (mean, median, variance, and standard deviation).
#
# Use only ideas introduced through Lecture 4. You do not need lists beyond the
# provided NumPy recipes, loops, pandas, plots, percentiles, or boolean indexing.

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# The `ipynb` file type is the only accepted format.
#
# Save a copy before beginning. Reloading or disconnecting can revert the notebook to the
# instructor copy.

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Problem 1 (15 pts): From load data to strength
#
# Six tensile specimens were measured in the same order by a load frame and by a
# dimensional measurement. Maximum load is in kN and original cross-sectional area is in
# mm$^2$.

# %%
import numpy as np

max_load_kN = np.array([31.2, 28.2, 35.8, 30.1, 34.0, 29.4])
area_mm2 = np.array([62.4, 57.0, 70.2, 61.6, 67.2, 59.4])

# %% [markdown]
# (a) Convert the complete `max_load_kN` array to newtons. Use
# $1\ \mathrm{kN} = 1000\ \mathrm{N}$ and print the result.
#
# (b) Compute the ultimate tensile strength of every specimen using
#
# $$\mathrm{strength} = \frac{\mathrm{maximum\ load\ (N)}}{\mathrm{area\ (mm^2)}}.$$
#
# Because $1\ \mathrm{N/mm^2}=1\ \mathrm{MPa}$, the resulting numbers are in MPa. Print the
# complete strength array, then print its minimum and maximum as labeled f-strings rounded to
# 2 decimal places.
#
# (c) Suppose `area_mm2` were sorted before the division but `max_load_kN` were left in its
# original order. The calculation would still run. In one or two sentences, explain why its
# results would no longer describe these specimens correctly.

# %%
# your code here

# %% [markdown]
# *Your answer to part (c) here.*

# %% [markdown]
# # Problem 2 (25 pts): Finding structure in the periodic table
#
# Run the next cell to load five parallel NumPy arrays from the same real periodic-table data
# used in Lecture 3. All arrays are ordered by atomic number, so position `i` refers to the same
# element in every array.

# %%
#@title Load the real periodic-table dataset (click ▶ to run, data loading, not a learning objective) { display-mode: "form" }
import os

import numpy as np
import pandas as pd

_file = 'mendeleev_elements.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}',
                 f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    _table = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e

symbol = _table['symbol'].to_numpy()
atomic_number = _table['atomic_number'].to_numpy()
radius_pm = _table['covalent_radius_cordero'].to_numpy()
density = _table['density'].to_numpy()
atomic_weight = _table['atomic_weight'].to_numpy()

print(f'Loaded {len(symbol)} elements from {_file}')
# Out:
# Loaded 118 elements from mendeleev_elements.csv

# %% [markdown]
# (a) Sulfur has atomic number 16. Use zero-based indexing to print its symbol, atomic number,
# atomic weight, and density. Do not type the values directly.
#
# (b) Use negative indexing to print the symbol and atomic number of the final element in the
# dataset.
#
# (c) Period 3 runs from sodium (index 10) through argon (index 17). Use slices to print the
# symbols and atomic weights for the complete period.
#
# (d) Use fancy indexing with the provided positions to print the symbols and covalent radii
# of the group 2 elements Be, Mg, Ca, Sr, Ba, and Ra.
#
# ```python
# group_2_positions = [3, 11, 19, 37, 55, 87]
# ```
#
# (e) Imagine that `atomic_weight` had been sorted from smallest to largest while `symbol`
# stayed in atomic-number order. Explain why looking up both arrays with the same index would
# then be scientifically invalid even though the Python syntax is valid.

# %% [markdown]
# ### (a) Sulfur lookup

# %%
# your code here

# %% [markdown]
# ### (b) Final element

# %%
# your code here

# %% [markdown]
# ### (c) Period 3 slice

# %%
# your code here

# %% [markdown]
# ### (d) Group 2 fancy indexing

# %%
group_2_positions = [3, 11, 19, 37, 55, 87]
# your code here

# %% [markdown]
# ### (e) Position as a contract
#
# *Your answer here.*

# %% [markdown]
# # Problem 3 (25 pts): Hardness across a plate
#
# A lab made three hardness traverses across a heat-treated steel plate. Each row is one
# traverse. Each column is the same position from the left edge to the right edge. Every value
# is Rockwell C hardness (HRC).

# %%
hardness_map = np.array([
    [59.8, 59.0, 58.2, 58.0, 58.9, 59.7],
    [59.5, 58.8, 57.9, 57.8, 58.7, 59.4],
    [59.9, 59.1, 58.1, 57.9, 59.0, 59.8],
])

# %% [markdown]
# (a) Print `hardness_map.shape`. In one sentence, explain what each number in the shape means
# for this experiment.
#
# (b) Using 2D indexing, print the fourth position in the second traverse. Also print the last
# reading in the last traverse using negative indices.
#
# (c) Use `:` to print the complete first traverse, then the complete third position across all
# three traverses.
#
# (d) Compute and print `np.mean(hardness_map, axis=0)` and
# `np.mean(hardness_map, axis=1)`. For each result, state what one returned number represents
# physically and report the result's `.shape`.
#
# (e) You want to determine whether the center of the plate is softer than its edges. Which of
# the two mean arrays from part (d) answers that question? Briefly interpret its values.

# %% [markdown]
# ### (a) Shape

# %%
# your code here

# %% [markdown]
# *Your shape interpretation here.*

# %% [markdown]
# ### (b) Two individual readings

# %%
# your code here

# %% [markdown]
# ### (c) One row and one column

# %%
# your code here

# %% [markdown]
# ### (d) Means along both axes

# %%
# your code here

# %% [markdown]
# *Your axis interpretations here.*

# %% [markdown]
# ### (e) Edge-to-center interpretation
#
# *Your answer here.*

# %% [markdown]
# # Problem 4 (35 pts): Two heat-treatment lots
#
# Ten precipitation-hardened aluminum tensile coupons were tested from each of two
# heat-treatment lots. Yield strengths are in MPa.

# %%
lot_A = np.array([508, 511, 509, 512, 510, 507, 513, 509, 511, 510])
lot_B = np.array([470, 550, 485, 535, 500, 520, 495, 525, 480, 540])

# %% [markdown]
# (a) For each lot, use NumPy functions to compute and print the mean, median, standard
# deviation, minimum, and maximum. Label the results and round mean, median, and standard
# deviation to 2 decimal places.
#
# (b) The two lots have the same mean and median. Which lot is more consistent? Support your
# answer with at least two of the spread-related numbers from part (a).
#
# (c) For `lot_A`, calculate the population variance and population standard deviation by hand:
# compute the mean, deviations, squared deviations, their sum divided by `len(lot_A)`, and the
# square root. Do not call `np.var` or `np.std` until the final confirmation step. Confirm that
# your results match NumPy's defaults.
#
# (d) Sort `lot_B` with `np.sort`. Because it has an even number of values, calculate its median
# by hand from the two middle entries. Confirm with `np.median`.
#
# (e) Make a copy of `lot_A`, replace its first value with `650`, and print the mean and median
# before and after the change. Which statistic moves more, and why?
#
# (f) Compute the standard deviation of `lot_A` once with NumPy's default and once with
# `ddof=1`. If these ten coupons are a sample used to estimate the behavior of an ongoing
# manufacturing process, which value is the appropriate estimate? Explain briefly.
#
# (g) The value `650` in part (e) is statistically unusual, but that alone does not prove it
# should be deleted. Give two physically plausible explanations for the reading and one useful
# follow-up check before deciding whether to reject it.

# %% [markdown]
# ### (a) NumPy summaries

# %%
# your code here

# %% [markdown]
# ### (b) Consistency comparison
#
# *Your answer here.*

# %% [markdown]
# ### (c) Variance and standard deviation by hand

# %%
# your code here

# %% [markdown]
# ### (d) Median by hand

# %%
# your code here

# %% [markdown]
# ### (e) Sensitivity to an unusual value

# %%
# your code here

# %% [markdown]
# *Your interpretation here.*

# %% [markdown]
# ### (f) Population or sample standard deviation

# %%
# your code here

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# ### (g) Statistical flag, materials decision
#
# *Your answer here.*

# %% [markdown]
# # Wrap-up
#
# This homework follows one data-analysis ladder: elementwise arithmetic turns raw
# measurements into a property; indexing and slicing select meaningful materials records;
# shape and axis preserve the physical organization of a 2D experiment; and center plus spread
# distinguish two manufacturing lots that a mean alone makes look identical.
