# %% [markdown]
# # Homework 3: Lists, dictionaries, and reading tabular data with Pandas

# %% [markdown]
# This homework covers two lectures:
# * **Lecture 7** (lists, dictionaries, and general indexing) -- Problems 1-2
# * **Lecture 8** (reading tabular data with Pandas) -- Problems 3-4
#
# Problems 3-4 use `dataset_elements` -- the same 52-element table from Lecture 8, with several
# columns that have real `NaN` gaps. No plotting and no boolean/logical filtering yet -- both
# are coming in later lectures (9 and 11).

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# *Only* the `ipynb` file type will be accepted.
#
# Save a copy of the notebook right away to avoid losing your work!

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Problem 1 (25 pts) -- Build and use a single `dict`
#
# (a) Build a `dict` called `material` describing a real material of your choosing (any metal,
# ceramic, or polymer you like), using the `{key: value, ...}` literal syntax from Lecture 7.
# Include at least these keys: `'name'`, `'symbol'` (or a short identifier if your material
# doesn't have one), `'density'`, `'melting_point'`, and `'category'`.
#
# (b) After building it, add **one new key** that wasn't in your original dict (e.g.
# `'crystal_structure'` or `'source'`), and **update** one of your existing keys with a more
# precise value -- the same "add one, update one" pattern Lecture 7 used on the `iron` dict.
#
# (c) Use `.get()` to look up a key you know is *not* in your dict, supplying a fallback default
# value of `'unknown'` instead of letting it raise a `KeyError`.
#
# (d) Loop over `material.items()` and print each key-value pair as a labeled line (e.g.
# `f"{key}: {value}"`), the same pattern Lecture 7 used to summarize `iron`.

# %% [markdown]
# ### (a) Build your material dict

# %%
# your code here

# %% [markdown]
# ### (b) Add one key, update one key

# %%
# your code here

# %% [markdown]
# ### (c) `.get()` with a default

# %%
# your code here

# %% [markdown]
# ### (d) Loop over `.items()`

# %%
# your code here

# %% [markdown]
# # Problem 2 (25 pts) -- A dict-of-lists
#
# Here's a dict-of-lists describing five metals, in the same style as Lecture 7's `elements`
# dict-of-lists:

# %%
metals = {
    'symbol':        ['Ti', 'Ni', 'Mg', 'Zn', 'Ag'],
    'name':          ['Titanium', 'Nickel', 'Magnesium', 'Zinc', 'Silver'],
    'density':       [4.51, 8.91, 1.74, 7.14, 10.49],
    'melting_point': [1668, 1455, 650, 420, 962],
}

# %% [markdown]
# (a) Tungsten (`'W'`, density `19.25` g/cm$^3$, melting point `3422` °C) is missing. Add it by
# calling `.append()` on **all four** lists -- one line per column, exactly like Lecture 7 added
# silver -- then print `metals` to confirm all four columns stayed the same length.
#
# (b) Using the two-step lookup pattern (`metals['column'][index]`), print the density of the
# **4th entry** (index 3) in the updated dict.
#
# (c) Using the same pattern, print the `name` of the metal now sitting at **index 5** -- the
# one you just added.
#
# (d) In a comment or short markdown cell: predict what happens if you run
# `metals['density'] + 1`. Then actually run it and confirm your prediction. Why does this fail
# when `np.array([...]) + 1` (Lecture 2) works fine?

# %% [markdown]
# ### (a) Append tungsten to all four lists

# %%
# your code here

# %% [markdown]
# ### (b) Density of the 4th entry

# %%
# your code here

# %% [markdown]
# ### (c) Name at index 5

# %%
# your code here

# %% [markdown]
# ### (d) `metals['density'] + 1` -- prediction and result
#
# *your prediction here*

# %%
# your code here

# %% [markdown]
# # Problem 3 (25 pts) -- Loading and exploring a real table
#
# Run the cell below to load the elemental-properties table from Lecture 8: 52 elements, 19
# columns of physical and electronic properties.

# %% [markdown]
# ## Dataset: Elemental Properties
#
# This dataset contains physical and electronic properties of chemical elements,
# including atomic mass, ionization energies, vacancy formation energies,
# bulk static energies, and crystal structures.
#
# Note that some entries contain `NaN` (Not a Number) values where data was
# unavailable. We'll need to handle these when performing calculations.

# %%
import os
import pandas as pd

_file = 'elements.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}', f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    data = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e
data
# Out:
#    Symbol  Bulk Static Energy (eV)  Reference Energy (eV)  Clean Cohesive  \
# 0      Ac              -442.228190                  -0.25             1.0
# 1      Ag              -305.971040                  -0.35             1.0
# 2      Al              -403.993240                  -0.23             1.0
# 3      Ar                -7.404033                  -0.05             1.0
# 4      Au              -353.846200                  -0.28             1.0
# 5      Ba                      NaN                    NaN             0.0
# 6      Be              -395.309910                  -0.01             1.0
# 7      Ca              -216.424440                  -0.13             1.0
# 8      Cd                      NaN                    NaN             0.0
# 9      Ce              -640.664090                  -1.27             1.0
# 10     Co              -746.519270                  -1.34             1.0
# 11     Cu              -402.331380                  -0.25             1.0
# ...

# %% [markdown]
# (a) Print `data.shape`, `data.columns`, and `data.dtypes`. In a comment, report how many
# columns are numeric (`float64`/`int64`) and how many store text (`object`).
#
# (b) Select the `'Atomic Mass'` column by itself (single brackets -- this gives you a
# `Series`). Print its `type()`, then print its `.mean()`, `.std()`, and `.median()`.
#
# (c) Select `'Cohesive Energy Per Atom (eV)'` and `'Atomic Mass'` together as a two-column
# `DataFrame` (remember the double brackets), and display the result.

# %% [markdown]
# ### (a) Shape, columns, dtypes

# %%
# your code here

# %% [markdown]
# ### (b) Select `'Atomic Mass'` and summarize it

# %%
# your code here

# %% [markdown]
# ### (c) Select two columns together

# %%
# your code here

# %% [markdown]
# # Problem 4 (25 pts) -- `.describe()`, `.value_counts()`, and row selection
#
# Still using `data` from Problem 3.
#
# (a) Call `data.describe()`. Find the `'Atomic Mass'` column in the output and confirm, in a
# comment, that its `mean`, `std`, and `50%` match the `.mean()`, `.std()`, and `.median()` you
# computed by hand in Problem 3(b) -- this is the "victory lap" Lecture 8 promised.
#
# (b) Call `data['STP Phase'].value_counts()`. In a comment, report which phase is most common
# among these 52 elements and how many elements have it.
#
# (c) Use `.iloc` to select the *last* row of `data` (hint: negative indices work here too).
# Then use `.loc` to print just the `'Symbol'` value of the element in row `0`.
#
# (d) Run `data.isna().sum()`, sort it with `.sort_values(ascending=False)`, and report (in a
# comment) which column has the most missing values and how many.

# %% [markdown]
# ### (a) `.describe()` and the victory lap

# %%
# your code here

# %% [markdown]
# ### (b) `.value_counts()` on `'STP Phase'`

# %%
# your code here

# %% [markdown]
# ### (c) `.iloc` and `.loc`

# %%
# your code here

# %% [markdown]
# ### (d) Missing values, sorted

# %%
# your code here

# %% [markdown]
# # Wrap-up
#
# Problems 1-2 were the two container types that don't force everything to be the same type --
# `dict` for labeled lookup, dict-of-lists for a hand-built table. Problems 3-4 showed why you
# rarely build tables by hand once your data gets real: `pd.read_csv` handed you the same
# dict-of-lists *shape*, but scaled to 52 rows and 19 columns, with every statistic from
# Lectures 4-5 just one method call away. Next time, we turn `.describe()`'s numbers into
# pictures.
