# %% [markdown]
# # Homework 4: Plotting and Filtering
#
# This homework covers two lectures:
# * **Lecture 9** (plotting with `matplotlib`) -- Problems 1-2
# * **Lecture 11** (comparisons and logical indexing) -- Problems 3-4
#
# Two datasets, both already familiar from lecture:
# * `dataset_periodic` -- 14 metallic elements with density, melting point, stiffness, etc.
#   (Lectures 8-9)
# * `dataset_elements` -- 52 elements with atomic-scale computed properties, several columns with
#   real `NaN` gaps (Lecture 8, reused in Lecture 11)
#
# <!--
# Not yet available: a planned Problem 5 was meant to use a live Materials Project pull
# (a small LiFeO-family teaser dataset) introduced in Lecture 10. Lecture 10 is currently
# blocked on a Materials Project API key not being available in this environment, so that
# dataset does not exist yet and is intentionally omitted here. Add it back once Lecture 10
# is unblocked and a real `dataset_mp_teaser` module exists -- do not fake the data in the
# meantime.
# -->

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Problem 1 (25 pts) -- Reproducing and extending Lecture 9's plots
#
# Using the periodic table dataset from Lecture 9:
#
# (a) Build a `fig, ax` scatter plot of `Electronegativity` (x-axis) against
# `Density (g/cm^3)` (y-axis). Label both axes (with units) and give it a title stating the
# question it answers.
#
# (b) Build a `fig, ax` histogram of `Young's Modulus (GPa)` using `bins=8`. Label both axes and
# give it a title. (Note: `Atomic Radius` in this dataset is stored as text with a unit suffix,
# e.g. `'0.128 nm'` -- not a plain number -- so it can't be histogrammed directly with tools
# you've seen so far. Stick to numeric columns like this one for now.)
#
# (c) Save the scatter plot from part (a) to a file named `problem1_scatter.png`, using
# `dpi=300` and `bbox_inches='tight'`.

# %% [markdown]
# ## Dataset: Periodic Table Properties
#
# This dataset contains basic physical and chemical properties of chemical elements
# from the periodic table, including standard atomic weight, density, atomic radius,
# electronegativity, melting point, and crystal structure.
#
# Columns include: `Element`, `Standard Atomic Weight`, `Density (g/cm^3)`,
# `Atomic Radius`, `Electronegativity`, `Melting Point`, `Structure`, and others.

# %%
import os
import pandas as pd

_file = 'periodic_table.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}', f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    data = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e
data
# Out:
#    Element  Standard Atomic Weight Atomic Radius Structure  Electronegativity  \
# 0       Cu                 63.5460      0.128 nm       FCC                1.8
# 1       Ni                 58.6934      0.125 nm       FCC                1.8
# 2       Al                 26.9810      0.143 nm       FCC                1.5
# 3       Zn                 65.3800      0.133 nm       HCP                1.7
# 4       Pb                207.2000      0.175 nm       FCC                1.6
# 5       Sc                 44.9550      0.162 nm       HCP                1.4
# 6       Ti                 47.8670      0.147 nm       HCP                1.5
# 7        V                 50.9415      0.134 nm       BCC                1.6
# 8       Cr                 51.9961      0.128 nm       BCC                1.7
# 9       Ga                 69.7230      0.135 nm     ORTHO                1.8
# 10      Sn                118.7100      0.140 nm       BCT                1.9
# ...

# %% [markdown]
# ### (a) Electronegativity vs. Density

# %%
# your code here

# %% [markdown]
# ### (b) Histogram of Atomic Radius

# %%
# your code here

# %% [markdown]
# ### (c) Save the part (a) scatter plot

# %%
# your code here

# %% [markdown]
# # Problem 2 (25 pts) -- Multi-panel figure with a filtered comparison
#
# This problem previews Lecture 11: you'll build a boolean mask on the `Structure` column
# *before* plotting with it.
#
# (a) Build two boolean masks on `data['Structure']`: one for rows equal to `'FCC'`, and one for
# rows that are *not* `'FCC'` (hint: `~`). Use each mask to build two filtered DataFrames,
# `fcc` and `non_fcc`.
#
# (b) Build a `1x2` figure with `plt.subplots(1, 2, figsize=...)`:
# * left panel (`axes[0]`): a scatter plot of `Standard Atomic Weight` (x) vs.
#   `Melting Point (K)` (y), with the `fcc` and `non_fcc` groups plotted as two separate series
#   (two `ax.scatter` calls, each with its own `label=`), a legend, axis labels, and a title.
# * right panel (`axes[1]`): a histogram of `Poisson Ratio` for the *whole* dataset (not split by
#   group), labeled and titled.
#
# Call `plt.tight_layout()` before `plt.show()`.

# %% [markdown]
# ### (a) Build the FCC / non-FCC masks

# %%
# your code here

# %% [markdown]
# ### (b) Build the 1x2 figure

# %%
# your code here

# %% [markdown]
# # Problem 3 (25 pts) -- Multi-condition filtering
#
# Switch to the elements dataset (52 elements, several atomic-scale computed properties).

# %% [markdown]
# ## Dataset: Elemental Properties
#
# This dataset contains physical and electronic properties of chemical elements,
# including atomic mass, ionization energies, vacancy formation energies,
# bulk static energies, and crystal structures.
#
# Note that some entries contain `NaN` (Not a Number) values where data was
# unavailable. We'll need to handle these when performing calculations.

# %%
import os
import pandas as pd

_file = 'elements.csv'
_github = f'https://raw.githubusercontent.com/wfreinhart/matse219/main/datasets/{_file}'
_local = next(
    (p for p in (f'datasets/{_file}', f'../datasets/{_file}', f'../../datasets/{_file}', f'../../../datasets/{_file}')
     if os.path.exists(p)),
    None,
)

try:
    data = pd.read_csv(_local if _local else _github)
except Exception as e:
    raise RuntimeError(
        f"Could not load '{_file}'. If you are in Colab, check your internet "
        f"connection and that the file exists at {_github}"
    ) from e
data
# Out:
#    Symbol  Bulk Static Energy (eV)  Reference Energy (eV)  Clean Cohesive  \
# 0      Ac              -442.228190                  -0.25             1.0
# 1      Ag              -305.971040                  -0.35             1.0
# 2      Al              -403.993240                  -0.23             1.0
# 3      Ar                -7.404033                  -0.05             1.0
# 4      Au              -353.846200                  -0.28             1.0
# 5      Ba                      NaN                    NaN             0.0
# 6      Be              -395.309910                  -0.01             1.0
# 7      Ca              -216.424440                  -0.13             1.0
# 8      Cd                      NaN                    NaN             0.0
# 9      Ce              -640.664090                  -1.27             1.0
# 10     Co              -746.519270                  -1.34             1.0
# 11     Cu              -402.331380                  -0.25             1.0
# ...

# %% [markdown]
# (a) Build a boolean mask, `cond_a`, for rows where `Cohesive Energy Per Atom (eV)` is greater
# than `3.0`.
#
# (b) Build a second mask, `cond_b`, for rows where `Atomic Mass` is greater than `100`.
#
# (c) Combine `cond_a` and `cond_b` with `&` to filter `data` down to just those rows, and display
# only the `Symbol`, `Cohesive Energy Per Atom (eV)`, and `Atomic Mass` columns of the result.
#
# (d) Separately, build a mask using `.isin(...)` for rows where `Natural Crystal Structure` is
# either `'fcc'` or `'hcp'`, combine it with `cond_a` from part (a), and display the same three
# columns (plus `Natural Crystal Structure`) for the result. How many rows satisfy both
# conditions?

# %% [markdown]
# ### (a)-(c) Cohesive energy and phase

# %%
# your code here

# %% [markdown]
# ### (d) Cohesive energy and crystal structure

# %%
# your code here

# %% [markdown]
# # Problem 4 (25 pts) -- Missing data
#
# Still using the elements dataset from Problem 3.
#
# (a) Using `.isna().sum()`, print the number of missing values in *every* column, sorted from
# most missing to least (hint: `.sort_values(ascending=False)`).
#
# (b) Pick the column with the *most* missing values from your sorted list in (a). Build a mask
# using `.notna()` on that column, use it to filter `data`, and report how many rows remain.
#
# (c) Confirm your answer to (b) a second way, using `data.dropna(subset=[...])` on the same
# column -- the row counts should match.
#
# (d) In a sentence or two: what happens if you call `data.dropna()` with no `subset` argument on
# this dataset, and why is that almost never what you actually want?

# %% [markdown]
# ### (a) Missing values per column

# %%
# your code here

# %% [markdown]
# ### (b) Filter on your chosen column

# %%
# your code here

# %% [markdown]
# ### (c) Confirm with `dropna(subset=...)`

# %%
# your code here

# %% [markdown]
# ### (d) Bare `dropna()` -- your answer
#
# *your answer here*
