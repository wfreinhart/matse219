# %% [markdown]
# # Homework 2: NumPy arrays, indexing, and descriptive statistics

# %% [markdown]
# This homework covers four lectures:
# * **Lecture 2** (NumPy arrays as vectors) -- Problem 1
# * **Lecture 3** (indexing, slicing, and array shape) -- Problem 2
# * **Lecture 4** (descriptive statistics I) -- Problem 3
# * **Lecture 5** (descriptive statistics II: percentiles and your first histogram) -- Problems
#   4-5
#
# Every array in this homework is provided as a literal `np.array(...)` right in the problem
# cell, the same way Lectures 2 and 3 built their arrays -- no `list`s, no `pandas`, and no
# Matplotlib beyond the single `plt.hist` recipe from Lecture 5.

# %% [markdown]
# ## Submission instructions
#
# Upload the `ipynb` file to Canvas:
# > File -> Download -> ipynb -> upload to Canvas (like any other file)
#
# *Only* the `ipynb` file type will be accepted.
#
# Save a copy of the notebook right away to avoid losing your work!

# %% [markdown]
# # Problem 0 (0 pts): generative AI usage statement
#
# As you work on this assignment, feel free to use generative AI tools to help you learn,
# understand, and debug Python code. In particular, you could get hints or conceptual guidance in
# the implementation you write yourself.
#
# However, you must clearly disclose and cite all use of AI. You must include:
# 1. The name(s) of the AI tool(s) used.
# 2. The specific prompt(s) you used to generate the content.
# 3. A description of how you used the output and what edits or additions you made to integrate it
#    into your own work.
#
# You are fully responsible for the final submitted work -- critically evaluate, fact-check, and
# verify all AI-generated content for validity. Failure to properly cite and disclose AI use
# constitutes plagiarism under Penn State's Academic Integrity policy.
#
# Write your disclosure (or "I did not use an AI tool for this assignment") in the cell below.

# %% [markdown]
# *your disclosure here*

# %% [markdown]
# # Problem 1 (20 pts) -- Array arithmetic: from density and volume to mass
#
# Eight machined samples of different metals were measured. Their densities (g/cm$^3$) and
# volumes (cm$^3$) are given below, in the same order.

# %%
import numpy as np

density = np.array([2.70, 4.51, 7.85, 8.91, 8.96, 7.14, 10.49, 19.25])  # g/cm^3
volume  = np.array([12.0, 8.5, 15.0, 6.0, 10.0, 9.5, 4.0, 3.0])          # cm^3

# %% [markdown]
# (a) Compute `mass = density * volume` (this is Lecture 2's `density = mass / volume` pattern,
# run in reverse) and print the resulting 8-entry array.
#
# (b) Suppose the scale used to weigh every sample has a known `+0.05` g calibration offset.
# Using broadcasting (add a single number to the whole array, exactly like Lecture 2's
# `mass + 0.5` example), compute `mass_corrected` and print it.
#
# (c) Convert `mass_corrected` from grams to kilograms (broadcast: divide by `1000`) and print
# the result as `mass_corrected_kg`.
#
# (d) Using `.max()` and `.min()`, print the highest and lowest corrected mass. Then, by eye,
# comparing against the printed `density`/`volume` arrays above, identify which sample index
# (0-7) has the highest mass and which has the lowest.

# %% [markdown]
# ### (a) Compute mass

# %%
# your code here

# %% [markdown]
# ### (b) Broadcast the calibration offset

# %%
# your code here

# %% [markdown]
# ### (c) Convert to kilograms

# %%
# your code here

# %% [markdown]
# ### (d) Highest and lowest mass

# %%
# your code here

# %% [markdown]
# # Problem 2 (20 pts) -- Indexing, slicing, and 2D arrays
#
# Ten metals and their thermal conductivity (W/m$\cdot$K) at room temperature:

# %%
metals = np.array(['Al', 'Ti', 'Fe', 'Ni', 'Cu', 'Zn', 'Ag', 'Sn', 'W', 'Au'])
conductivity = np.array([237, 21.9, 80.4, 90.9, 401, 116, 429, 66.8, 173, 317])  # W/(m*K)

# %% [markdown]
# (a) Using zero-based indexing, print the symbol and conductivity of the **6th metal** in the
# list above (remember index 0 is the 1st metal).
#
# (b) Using negative indexing (no counting how many entries there are), print the symbol and
# conductivity of the **last** metal in the list.
#
# (c) Using a slice, print the symbol and conductivity arrays for the **first 4** metals.
#
# (d) Copper, silver, and tungsten are the three best conductors in copper wiring, silver
# contacts, and tungsten filaments respectively. Using **fancy indexing** with a list of their
# positions (`[4, 6, 8]`), print their symbols and conductivities in one line each.
#
# (e) Here is a second property, density (g/cm$^3$), for the same 10 metals in the same order:

# %%
density10 = np.array([2.70, 4.51, 7.87, 8.91, 8.96, 7.14, 10.49, 7.31, 19.25, 19.32])  # g/cm^3

# %% [markdown]
# Stack `conductivity` and `density10` into a single 2D array called `properties` (the same way
# Lecture 3 stacked `melting_K` and `radius_pm`), print its `.shape`, then use 2D indexing
# (`properties[row, col]`) to print the density of copper and the full column (`properties[:,
# ...]`, both properties at once) for silver.

# %% [markdown]
# ### (a) 6th metal (zero-based indexing)

# %%
# your code here

# %% [markdown]
# ### (b) Last metal (negative indexing)

# %%
# your code here

# %% [markdown]
# ### (c) First 4 metals (slice)

# %%
# your code here

# %% [markdown]
# ### (d) Cu, Ag, W (fancy indexing)

# %%
# your code here

# %% [markdown]
# ### (e) 2D array: shape, and copper/silver lookups

# %%
# your code here

# %% [markdown]
# # Problem 3 (25 pts) -- Descriptive statistics, by hand and with NumPy
#
# Two bolt suppliers, A and B, both claim to meet the same 900 MPa minimum yield strength spec.
# Here are 15 yield-strength readings (MPa) from each:

# %%
batch_A = np.array([912.3, 908.1, 915.6, 906.4, 910.2, 913.8, 907.5, 911.0,
                     909.4, 914.1, 908.8, 912.7, 906.9, 910.6, 909.9])
batch_B = np.array([889.4, 921.7, 903.5, 934.2, 887.1, 916.8, 898.0, 928.4,
                     892.6, 910.3, 940.1, 884.9, 917.5, 901.2, 924.8])

# %% [markdown]
# (a) Compute the mean and standard deviation of `batch_A` **by hand only** -- `np.sum`, `len`,
# and the deviation-squaring formula from Lecture 4 (`np.sqrt(np.sum((x - mean)**2) / N)`).
# **Do not use `np.mean` or `np.std` in this part.** Do the same for `batch_B`.
#
# (b) Now confirm both results using `np.mean` and `np.std` directly, and print both the
# by-hand and NumPy versions side by side so you can see they agree.
#
# (c) In a sentence or two: which supplier's bolts are more *consistent*, and how do you know
# from the numbers (not just eyeballing the raw readings)?
#
# (d) A separate batch of 9 pore-size measurements (microns) from a sintered ceramic:
# ```python
# pore_size = np.array([12.4, 15.1, 11.8, 14.0, 13.2, 16.5, 12.9, 13.7, 14.8])
# ```
# Sort this array with `np.sort`, then compute its median **by hand** (since $N=9$ is odd,
# there's a single middle value -- no averaging needed) and its variance **by hand**
# (`np.sum((x - mean)**2) / N`, no square root this time). Confirm both against `np.median` and
# `np.var`.

# %% [markdown]
# ### (a) Mean and std by hand

# %%
# your code here

# %% [markdown]
# ### (b) Confirm with np.mean / np.std

# %%
# your code here

# %% [markdown]
# ### (c) Which supplier is more consistent? -- your answer
#
# *your answer here*

# %% [markdown]
# ### (d) Median and variance by hand, pore_size

# %%
pore_size = np.array([12.4, 15.1, 11.8, 14.0, 13.2, 16.5, 12.9, 13.7, 14.8])
# your code here

# %% [markdown]
# # Problem 4 (15 pts) -- Percentiles and IQR
#
# Porosity (%) measurements from 40 sintered ceramic specimens:

# %%
rng = np.random.default_rng(11)
porosity = rng.normal(loc=6.0, scale=1.3, size=40)
porosity = np.round(porosity, 2)
print(porosity)
# Out:
# [6.04 7.77 7.59 5.34 5.61 5.31 6.74 5.93 6.97 3.6  8.04 5.87 6.88 5.82
#  5.51 6.6  7.07 5.74 5.8  6.89 4.87 4.03 6.51 5.13 3.5  4.94 5.39 4.45
#  4.06 6.05 7.17 5.7  5.03 6.5  6.93 5.61 6.71 7.36 5.73 4.94]

# %% [markdown]
# (a) Using a single `np.percentile` call, compute Q1, the median, and Q3 of `porosity`. Compute
# the IQR (`Q3 - Q1`).
#
# (b) Using a second `np.percentile` call, compute the 10th and 90th percentiles, and their
# difference (the "80% spread"), the same way Lecture 5's check-your-understanding did for
# `grain_size`.
#
# (c) Which is bigger, the IQR or the 80% spread? In one sentence, explain why that makes sense
# given what each one measures.

# %% [markdown]
# ### (a) Q1, median, Q3, IQR

# %%
# your code here

# %% [markdown]
# ### (b) 10th/90th percentile and the 80% spread

# %%
# your code here

# %% [markdown]
# ### (c) IQR vs. 80% spread -- your answer
#
# *your answer here*

# %% [markdown]
# # Problem 5 (20 pts) -- Histogram interpretation
#
# A materials lab measured the size (microns) of 300 small inclusion defects found during a
# polished-section inspection:

# %%
import matplotlib.pyplot as plt

rng2 = np.random.default_rng(7)
defect_size = rng2.lognormal(mean=np.log(15), sigma=0.6, size=300)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# (a) Using the one-line `plt.hist` recipe from Lecture 5 (`plt.hist(data, bins=20)` then
# `plt.show()`), plot a histogram of `defect_size`.
#
# (b) Compute `np.mean(defect_size)` and `np.median(defect_size)` and print both.
#
# (c) In 2-3 sentences: is this distribution symmetric or skewed? Which way? Is the mean or the
# median a better "typical value" to report for this data, and why -- connect your answer to
# what you found in part (b).

# %% [markdown]
# ### (a) Histogram of defect_size

# %%
# your code here

# %% [markdown]
# ### (b) Mean and median

# %%
# your code here

# %% [markdown]
# ### (c) Symmetric or skewed? Mean or median? -- your answer
#
# *your answer here*

# %% [markdown]
# # Wrap-up
#
# This homework is Lectures 2-5's entire toolkit -- array creation and elementwise math,
# indexing/slicing (including a first 2D array), the full by-hand-and-NumPy descriptive
# statistics pair, percentiles, and one histogram -- applied to new numbers on the same kinds of
# materials questions. If any of your printed values look physically strange (a negative mass,
# a density nowhere near a real metal), stop and check your formula before moving on -- that's
# the same sanity-check habit from Lecture 1, just applied to whole arrays now.
